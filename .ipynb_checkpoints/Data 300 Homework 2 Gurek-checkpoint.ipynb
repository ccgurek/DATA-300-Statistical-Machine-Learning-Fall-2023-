# %% [markdown]
# #### 39/43. Good job

# %% [markdown]
# 1. Three time series models that can be used for forecasting are Moving Averages, ARIMA models, and Neural Networks.

# %% [markdown]
# 2. One real world application is the use of time series forecasting to predict future daily sales in retail stores, I work in retail and we are given a sales goal every day and every hour that is based on past data from days in past years, past seasons, etc. A second example would be the forecasting the weather, we know what the typical seasons look like from past years so we use that to predict what the weather will be like in the coming months.

# %% [markdown]
# 3. The difference between a time series and panel data set is that a time series data set only has one variable recorded over different times, while a panel data set has more than one variable that is being recorded over different times.

# %% [markdown]
# 4. The major difference in selecting training sets in time series machine learning tasks as compared to regression/ classification tasks is that you do not shuffle the terms before selecting. If they are shuffled then you risk using future data to predict past data, which just isn’t logical.

# %% [markdown]
# 5. a. Stationarity is when there is no predictable trend or pattern within the data.
#
# b. Differencing is a method of transforming the data by subtracting the current value in the series from a previous one or a lagged value, this process can be used to make the data stationary.
#
# c. White noise is a series of observations that are independently and identically distributed with a mean of 0 and a constant variance.
#
# d. A Random Walk is a series of observations where the current observation is equal to the previous observation with a random step up/down.

# %% [markdown]
# 6. a. This equation would be an example of an ARMA model, which uses the combination of past observations and past errors for prediction. The c and 𝜖𝜏 terms are the equivalence of intercepts, the c being the value with no previous p stamps, and the 𝜖𝜏 being the expected error term at that time. The first summation equation represents the autoregressive(AR) portion of the model, or the part that uses previous p-stamps to predict the current time’s stamp. The Øi in this equation is the first order autocorrelation coefficient. The second summation represents the Moving average(MA) portion of the model, or the part that uses past errors to predict the current value at time t. The θi in this equation is the coefficient for the lag number that is used, lag t. The 𝜀t-1 is the first order moving average paramter. Thus this equation would give us the predicted value of X at time t when you use 3 lags of autoregression and 4 lags of moving averages for your prediction.
#
# b. No, we cannot tell from the above equation if it has been differenced or not. At this point the data would have already been plotted and differenced accordingly before building the model.
#
# c. The autoregressive order would be AR(3) and the Moving Average order would be MA(4).
#
# d. You decide the AR order by creating a PACF, or Partial Autocorrelation Function plot, this plot lets you decide how many lags to use based on how many points are significant as shown on the plot. If the first and the third points are significant, then you include 3 lags. You decide the MA order by creating an ACF, or Autocorrelation Function plot, this plot functions the same as a PACF plot so the lag order is decided by the amount of significant points in the same way as the AR order with the PACF plot.

# %% [markdown]
# #### Very well done on the theory part

# %%
#python 3.9.13  #conda 23.1.0

# %%
#import the needed packages

import pandas as pd # version 1.4.4
import numpy as np # version 1.21.5
import statsmodels.api as sm # version 0.13.2
import pmdarima as pm #version 2.0.3
import matplotlib.pyplot as plt # version 3.5.2
import pandas_profiling as pp # version 3.6.6
import warnings as ww
import statsmodels.tsa.stattools as stattools  # version 0.13.2

from statsmodels.tsa.stattools import adfuller # version 0.13.2
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf # version 0.13.2
from statsmodels.tsa.arima_model import ARIMA # version 0.13.2

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
# Out:
# /var/folders/00/zf18np857gbg8pz_r_jnmjsw0000gn/T/ipykernel_33824/1129380698.py:8: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as pp # version 3.6.6

# %%
#allows the matplotlib plots to be shown

ww.filterwarnings("ignore")
# %matplotlib inline

# %%
#shows the version of packages used

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.4.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.3.0
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.11.7
# astropy                       5.1
# async-generator               1.10
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# ...

# %%
# reading in the data

ep = pd.read_csv("/Users/christinegurek/Desktop/GitHub/DATA-300-Statistical-Machine-Learning-Fall-2023-/Data/Electric_Production.csv")

# %%
#making sure the data is read correctly

ep
# Out:
#           DATE  IPG2211A2N
# 0     1/1/1985     72.5052
# 1     2/1/1985     70.6720
# 2     3/1/1985     62.4502
# 3     4/1/1985     57.4714
# 4     5/1/1985     55.3151
# ..         ...         ...
# 392   9/1/2017     98.6154
# 393  10/1/2017     93.6137
# 394  11/1/2017     97.3359
# 395  12/1/2017    114.7212
# 396   1/1/2018    129.4048
#
# [397 rows x 2 columns]

# %%
#this function tells us the names of the columns and the type of 
#data that the column names are

ep.columns
# Out:
# Index(['DATE', 'IPG2211A2N'], dtype='object')

# %%
# this function tells us the type of data that is in each column

ep.dtypes
# Out:
# DATE           object
# IPG2211A2N    float64
# dtype: object

# %%
# this function tells us the shape of the data, 
#thus there are 397 rows and 2 columns

ep.shape
# Out:
# (397, 2)

# %%
#this function tells us the total amount of missing values in each 
#column, in this case we are not missing any values

ep.isna().sum()
# Out:
# DATE          0
# IPG2211A2N    0
# dtype: int64

# %%
#this function gives us lots of information about the data, 
#the number of columns, missing data, etc.
#It also plots the data in a number of ways for us, histograms, 
#scatterplots, etc. This can help us see warnings in the data that 
# hand done EDA may not show us

pp.ProfileReport(ep)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-09-29 02:57:01.210987&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# 1. There is not much that stands out to me with this data. There are no missing values so we will not need to impute any. The only alerts we are given in the pandas profiling report was that there may be cardinality in the dates column, the dates column may be uniform, and that both columns have completely unique data points.

# %%
#this function turns the date column from just a text object into a 
#datetime object

ep["DATE"] = pd.to_datetime(ep["DATE"])

# %%
#to make sure the previous function changed the data type correctly

ep.dtypes
# Out:
# DATE          datetime64[ns]
# IPG2211A2N           float64
# dtype: object

# %%
#sorting the data in chronological order

ep = ep.sort_values("DATE")

# %%
# this function runs the KPSS test on both columns and returns the KPSS
#test statistic, the p-value of the test, the number of lags used, and 
#the critical values 

for i in ep.columns:
    print (i)
    print()
    print (stattools.kpss(ep[i], regression='ct'))
    print ()
# Out:
# DATE
#
# (0.01715323608505754, 0.1, 7, {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})
#
# IPG2211A2N
#
# (0.5051030832418347, 0.01, 16, {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
#this function runs the ADF test on both columns in the data set and 
#returns the ADF test statistic, the p-value of the test, the number of
#lags used, the number of observations used to complete the test, and
#the critical values

for i in ep.columns:
    print(i)
    print()
    print(adfuller(ep[i]))
    print()
# Out:
# DATE
#
# (-0.14017905755825988, 0.9452865588327521, 12, 384, {'1%': -3.4474946672686824, '5%': -2.8690962436986855, '10%': -2.570795299750434}, 24217.455634478458)
#
# IPG2211A2N
#
# (-2.2569903500472432, 0.18621469116586814, 15, 381, {'1%': -3.4476305904172904, '5%': -2.869155980820355, '10%': -2.570827146203181}, 1840.8474501627156)

# %% [markdown]
# 2. The test statistic for the KPSS test for the date is 0.01715323608505754 with a p-value of 0.1, and the ADF test statistic for the date is -0.14017905755825988 with a p-value of 0.9452865588327521. The test statistic for the KPSS test for IPG2211A2N is 0.5051030832418347 with a p-value of 0.01, and the ADF test statistic for IPG2211A2N is -2.2569903500472432 with a p-value of 0.18621469116586814. From this we can conclude that there is a very good chance that the two variables are not stationary; the ADF test and the KPSS tests have very different values, both of which lean towards showing non-stationarity, but we can also look at the plots before deciding further.

# %%
#### These two tests, just like we said in class are pointing towards non stationarity because they have inverted hypothesis tests.

# %%
#this function removes the dates column as it is not needed for the 
#differncing section

ep_no_dates=ep[['IPG2211A2N']]
ep_no_dates
# Out:
#      IPG2211A2N
# 0       72.5052
# 1       70.6720
# 2       62.4502
# 3       57.4714
# 4       55.3151
# ..          ...
# 392     98.6154
# 393     93.6137
# 394     97.3359
# 395    114.7212
# 396    129.4048
#
# [397 rows x 1 columns]

# %%
#this function plots the raw data so we can see if it is stationary
#or not, to me there is a clear trend so i'd say it is not stationary

for i, col in enumerate(ep_no_dates.columns):
    ep_no_dates[col].plot(fig=plt.figure(i))
    plt.title(col)
    
plt.show()

# %%
#this function differences the data once, and brings it to a more 
#stationary state

for i, col in enumerate(ep_no_dates.columns):
    ep_no_dates[col].diff().plot(fig=plt.figure(i))
    plt.title(col)

    plt.show()

# %%
#this function differences the data a third time, and bring the data 
#even closer to stationarity

for i, col in enumerate(ep_no_dates.columns):
    ep_no_dates[col].diff().diff().plot(fig=plt.figure(i))
    plt.title(col)

plt.show()

# %% [markdown]
# 3. The first, undifferenced graph has a very clear pattern, it seems to curve upward and to the right, while the second two have much less of a pattern. By the third graph there not only seems to be less of a pattern but the data also seems more centralized.

# %%
# this function creates ACF and PACF plots that are able to be shown 
#one after the other

def acf_pacf (series)-> plt.plot:
    return plot_acf(series), plot_pacf(series)

# %%
#this runs through both variables in the data and creates ACF and PACF
#plots for each of them

for i in ep.columns:
    print(i)
    acf_pacf(ep[i])
    print()
# Out:
# DATE
#
# IPG2211A2N

# %%
# this function creates and finds the optimal ARIMA model 
#for the time series data given

def arimamodel(timeseries):
    automodel = pm.auto_arima(timeseries, 
                              start_p=1, 
                              start_q=1,
                              test="adf",
                              seasonal=True,
                              trace=True)
    return automodel

# %% [markdown]
# #### For this class we said we were not supposed to use Auto ARIMA. And even if you used it, you use it on a stationary series. (-2)

# %%
#this finds the optimal ARIMA model for the IPG2211A2N data, which is
#ARIMA(4,0,2)

for i in ep_no_dates:
    print(i)
    arimamodel(ep_no_dates[i])
    print()
# Out:
# IPG2211A2N
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=2593.391, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=3300.096, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=2737.192, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=2897.340, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4702.955, Time=0.01 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=2582.998, Time=0.21 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=2641.805, Time=0.07 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=2274.583, Time=0.34 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=2461.876, Time=0.13 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=2242.133, Time=0.36 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=2309.696, Time=0.26 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : AIC=2226.764, Time=0.40 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.29 sec
# ...

# %% [markdown]
# 5. My final ARIMA order is ARIMA(4,0,2)

# %% [markdown]
# #### How did you decide your ARIMA is of order 4,0,2? (-2). If the data is non stationary, it needs to be differenced at least once.

# %%
# This function models the data off of your chosen test set, which I set
# at 80% of the data, and finds how well the model fits the data

model = sm.tsa.arima.ARIMA(ep['IPG2211A2N'].head(int(0.8*len(ep))), order=(4, 0, 2))
results = model.fit()

# %%
# this function shows us the summary of our ARIMA model and 
#its coefficients

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:             IPG2211A2N   No. Observations:                  317
# Model:                 ARIMA(4, 0, 2)   Log Likelihood                -880.305
# Date:                Thu, 28 Sep 2023   AIC                           1776.610
# Time:                        22:57:08   BIC                           1806.681
# Sample:                             0   HQIC                          1788.622
#                                 - 317
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         85.1488     27.780      3.065      0.002      30.702     139.596
# ar.L1          0.9364      0.053     17.612      0.000       0.832       1.041
# ar.L2          0.1433      0.054      2.646      0.008       0.037       0.249
# ...

# %%
#This function forecasts out using the chosen 80% test set to create
# a predicted model

ep['IPG2211A2N_forecast']=results.predict(start = int(0.8*len(ep))+1, end=len(ep) , dynamic=True)

# %%
#this function plots the actual data along with the forecasted model

ep[['IPG2211A2N','IPG2211A2N_forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
#these functions find the mean absolute error and the mean squared error
# which we can use to decide if the model is a good fit or not

MAE = mean_absolute_error(ep['IPG2211A2N_forecast'].tail(int(0.2*len(ep))),ep['IPG2211A2N'].tail(int(0.2*len(ep))))
MSE = mean_squared_error(ep['IPG2211A2N_forecast'].tail(int(0.2*len(ep))),ep['IPG2211A2N'].tail(int(0.2*len(ep))))
print("The mean absolute error is " + str(MAE))
print("The mean squared error is " + str(MSE))
# Out:
# The mean absolute error is 7.3409129729637295
# The mean squared error is 81.54933055076454

# %% [markdown]
# 9. Overall I do not think the model is very good. Although by looking at the forecasting plot, it seems like it starts out pretty strong and then really doesn't work very well towards the end. We also have a very large mean squared error, which would indicate that this is not a very good model. It may produce a better model if the data is differenced but I had a hard time plugging the differenced data into the functions.
